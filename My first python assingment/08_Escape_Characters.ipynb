# %% [markdown]
# #What is Escape Character?
# An escape character is a backslash (\) used inside a string to represent special characters or actions.
#
# For example, \n creates a new line:

# %%
print("Hello\nWorld")
# Out:
# Hello
# World

# %% [markdown]
# ##Some common escape character

# %% [markdown]
# ![escape character.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##Using character \ slash

# %%
txt = "We are the so-called "white" from the north."
# Out:
#   File "/tmp/ipykernel_1232/4287682424.py", line 1
#     txt = "We are the so-called "white" from the north."
#                                  ^
# SyntaxError: invalid syntax

# %%
txt = "We are the so-called \"white\" from the north."
print(txt)
# Out:
# We are the so-called "white" from the north.

# %% [markdown]
# ##creating a new tab

# %%
print("Hello\tWorld")
# Out:
# Hello	World

# %% [markdown]
# ##Displaying quotation marks inside text.

# %% [markdown]
# ##Using Apostrophe

# %%
txt = 'It\'s alright. He\'s brother is my brother.'
print(txt)
# Out:
# It's alright. He's brother is my brother.

# %% [markdown]
# ##Using backslash

# %%
txt = "He is so funny.He always\b make me happy."# This erease one character
print(txt)
# s is erase from always in output
# Out:
#  make me happy.

# %% [markdown]
# ##octol value

# %%
txt = "\110\145\154\154\157" # 110 mean H, 145 mean e and soon.
print(txt)
# Out:
# Hello
