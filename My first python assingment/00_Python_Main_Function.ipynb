# %% [markdown]
# #Python Programming Language

# %% [markdown]
# #What is Python?
#   Python is a popular, high-level programming language created by Guido van Rossum and released in 1991. Known for its simple, readable syntax, it is widely used for artificial intelligence, machine learning, web development, and task automation.
# ###Its Uses:
#
# 1. Data Science & AI: Powers smart tools, deep learning, and math  calculations using libraries like Pandas and NumPy.
# 2. Web Development: Builds the hidden back-end logic of websites via frameworks like Django and Flask.
# 3. Automation: Clears out boring, repetitive tasks like sorting files or parsing spreadsheets

# %%
#my frist python code
print("hello world")
# Out:
# hello world

# %% [markdown]
# ##What is Python syntax
# Python syntax is the set of rules that defines how a python program must be written and orgainzed for the computer to understand it.

# %% [markdown]
# ##Basics Syntax
# 1. def → keyword used to define a function.
# 2. function_name → name of the function.
# 3. () → parentheses for parameters.
# 4. : → indicates the beginning of the function body.
# 5. The indented code → statements executed when the function is called.

# %%
def my_function():# use of def and function_name with parenthese and colon

  print("Hello, World!") #use of indentation to excute the code

# %% [markdown]
# ##Python indentation
# Indentation in Python refers to the whitespaces (spaces or tabs) at the beginning of a line of code.

# %%
x = 7
if x>5:
  print("x is greater than 5")
  #python indentation program works
# Out:
# x is greater than 5

# %%
x = 7
if x>5:
print("x is greater than 5") # no indentation show error
# Out:
#   File "/tmp/ipykernel_1287/538571537.py", line 3
#     print("x is greater than 5")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %% [markdown]
# ##Comment in python
# A Python comment is a non-executable line of text within your script that the Python interpreter ignores completely during execution

# %%
#This is comment
print("hello world")
#comment are use to comment the codes

# %% [markdown]
# ##What is function ?
# A function in Python is a reusable block of code that performs a specific task.
# Instead of writing the same code repeatedly, we can write it once inside a function and call the function whenever we need it.

# %%
print("He is a good boy")
# Out:
# he is a good boy

# %%
print(He is a good boy) # this show a error , string need double quotation to run
# Out:
#   File "/tmp/ipykernel_1287/4128889740.py", line 1
#     print(he a good boy)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(4) # print integer does not need double quotation
print(354)
print(85009)
# Out:
# 4
# 354
# 85009

# %%
print("I am ", 25 , "years old.") # here we can use mix text and number using proper function.
# Out:
# I am  25 years old.

# %% [markdown]
# ##What are the uses of function?
# The uses of function are listed below:

# %% [markdown]
# 1. Avoid Code Repetition

# %%
print("hello world")
print("hello world")
print("hello world")

# %%
def welcome():
    print("Welcome to Python")

welcome()
welcome()
welcome() # while code is written once and it will reused for multiple times.

# %% [markdown]
# 2. Make Code Easier to Understand
#
# Functions divide a large program into smaller, meaningful tasks.

# %%
def calculate_total():
    # code for calculating total
    pass

def display_result():
    # code for displaying result
    pass

# %% [markdown]
# 3. Make Code Reusable

# %%
def square(number):
    return number * number

print(square(5))
print(square(10))
# code can be called and reused for different parts of a program.

# %% [markdown]
# 4. Make Programs Easier to Maintain
#
#     we can change the logic ,change it form one place

# %% [markdown]
# 5. Reduce Program Complexity
#
#       Functions break a large program into smaller pieces, making it easier to read, understand, test, and debug.
